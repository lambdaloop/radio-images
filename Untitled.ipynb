# %%
import util
import numpy as np
from encoding import *

# %%
data = np.zeros(1024000)
ixs = np.int32(np.random.random(size=50000)*(len(data)-10000))
data[ixs] = 1
print(np.sum(data))
# Out:
# 48753.0

# %%
x = util.compress(np.array(util.compress(data).tolist()))
recov = np.array(util.decompress(util.decompress(x)).tolist())
recov = np.int32(recov)
len(data), len(recov), len(x), len(util.compress(data))
# Out:
# (1024000, 1024000, 355576, 355408)

# %%
c = util.compress(data)

# %%
c[-1000:]
# Out:
# bitarray('...')

# %%
from encoding import *

# %%
dd = compressandencode('bird.jpg')
# Out:
# Found image with width 700 and height 700
# Finished transform to Y, Cb, Cr
# Got coefficients
# Compressed to 95056 bits

# %%
x = util.compress(np.array(dd.tolist()))

# %%
len(dd)
# Out:
# 95056

# %%
x[-2000:]
# Out:
# bitarray('...')
